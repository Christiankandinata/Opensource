    "PPRO.JK", "PRAS.JK", "PRDA.JK", "PRIM.JK", "PSAB.JK", "PSDN.JK", "PSGO.JK", "PSKT.JK", "PSSI.JK", "PTBA.JK", "PTIS.JK", "PTPP.JK", "PTPW.JK", "PTRO.JK", "PTSN.JK", "PTSP.JK", "PUDP.JK", "PURA.JK",
    "PURE.JK", "PWON.JK", "PYFA.JK", "PZZA.JK", "RAJA.JK", "RALS.JK", "RANC.JK", "RBMS.JK", "RDTX.JK", "REAL.JK", "RELI.JK", "RICY.JK", "RIGS.JK", "RIMO.JK", "RISE.JK", "RMBA.JK", "RODA.JK", "RONY.JK",
    "ROTI.JK", "RUIS.JK", "SAFE.JK", "SAME.JK", "SAMF.JK", "SAPX.JK", "SATU.JK", "SBAT.JK", "SCCO.JK", "SCMA.JK", "SCPI.JK", "SDMU.JK", "SDPC.JK", "SDRA.JK", "SFAN.JK", "SGER.JK", "SGRO.JK", "SHID.JK",
    "SHIP.JK", "SIDO.JK", "SILO.JK", "SIMA.JK", "SIMP.JK", "SINI.JK", "SIPD.JK", "SKBM.JK", "SKLT.JK", "SKRN.JK", "SKYB.JK", "SLIS.JK", "SMAR.JK", "SMBR.JK", "SMCB.JK", "SMDM.JK", "SMDR.JK", "SMGR.JK",
    "SMKL.JK", "SMMA.JK", "SMMT.JK", "SMRA.JK", "SMRU.JK", "SMSM.JK", "SOCI.JK", "SOFA.JK", "SONA.JK", "SOSS.JK", "SOTS.JK", "SPMA.JK", "SPTO.JK", "SQMI.JK", "SRAJ.JK", "SRIL.JK", "SRSN.JK", "SRTG.JK",
    "SSIA.JK", "SSMS.JK", "SSTM.JK", "STAR.JK", "STTP.JK", "SUGI.JK", "SULI.JK", "SUPR.JK", "SURE.JK", "SWAT.JK", "TALF.JK", "TAMA.JK", "TAMU.JK", "TARA.JK", "TAXI.JK", "TBIG.JK", "TBLA.JK", "TBMS.JK",
    "TCID.JK", "TCPI.JK", "TDPM.JK", "TEBE.JK", "TECH.JK", "TELE.JK", "TFAS.JK", "TFCO.JK", "TGKA.JK", "TGRA.JK", "TIFA.JK", "TINS.JK","TIRA.JK", "TIRT.JK", "TKIM.JK", "TLKM.JK", "TMAS.JK", "TMPO.JK",
    "TNCA.JK", "TOBA.JK", "TOPS.JK", "TOTL.JK", "TOTO.JK", "TOWR.JK", "TOYS.JK", "TPIA.JK", "TPMA.JK", "TRAM.JK", "TRIL.JK", "TRIM.JK", "TRIN.JK", "TRIO.JK", "TRIS.JK", "TRST.JK", "TRUK.JK", "TRUS.JK",
    "TSPC.JK", "TUGU.JK", "TURI.JK", "UANG.JK", "UCID.JK", "ULTJ.JK", "UNIC.JK", "UNIT.JK", "UNSP.JK", "UNTR.JK", "UNVR.JK", "URBN.JK", "VICO.JK", "VINS.JK", "VIVA.JK", "VOKS.JK", "VRNA.JK", "WAPO.JK",
    "WEGE.JK", "WEHA.JK", "WICO.JK", "WIIM.JK", "WIKA.JK", "WINS.JK", "WOMF.JK", "WOOD.JK", "WOWS.JK", "WSBP.JK", "WSKT.JK", "WTON.JK", "YELO.JK", "YPAS.JK", "YULE.JK", "ZBRA.JK", "ZINC.JK", "ZONE.JK"
]

# %%
today = date.today()
d1 = today.strftime("%Y-%m-%d")
d1

# We would like all available data from 01/01/2000 until 12/31/2016.
start_date = '2020-03-01'
end_date = d1

# User pandas_reader.data.DataReader to load the desired data. As simple as that.
df = data.DataReader(tickers, 'yahoo', start_date, end_date)
# Out:
# /Users/christianprasetya/anaconda/lib/python2.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CMPP.JK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/christianprasetya/anaconda/lib/python2.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'HDTX.JK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/christianprasetya/anaconda/lib/python2.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'MAMIP.JK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/christianprasetya/anaconda/lib/python2.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'MITI.JK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# ...

# %%
df2 = df['Close']
df_open = df['Open']

# %%
df2.tail()
# Out:
# Symbols     AALI.JK  ABBA.JK  ABDA.JK  ABMM.JK  ACES.JK  ACST.JK  ADES.JK  \
# Date
# 2020-10-02  10500.0     50.0   6575.0    855.0   1575.0    185.0   1125.0
# 2020-10-05  10475.0     50.0   6575.0    855.0   1565.0    185.0   1145.0
# 2020-10-06  10425.0     50.0   6575.0    855.0   1545.0    218.0   1170.0
# 2020-10-07  10375.0     50.0   6575.0    855.0   1545.0    210.0   1190.0
# 2020-10-08  10675.0     50.0      NaN    855.0   1560.0    204.0   1180.0
#
# Symbols     ADHI.JK  ADMF.JK  ADMG.JK  ...  WOWS.JK  WSBP.JK  WSKT.JK  \
# Date                                   ...
# 2020-10-02    500.0   7225.0    119.0  ...     78.0    137.0    500.0
# 2020-10-05    505.0   7200.0    120.0  ...     75.0    138.0    515.0
# 2020-10-06    525.0   7275.0    125.0  ...     89.0    145.0    540.0
# 2020-10-07    525.0   7400.0    133.0  ...     83.0    148.0    540.0
# 2020-10-08    540.0   7500.0    141.0  ...     78.0    148.0    545.0
#
# ...

# %%
df_open.index
# Out:
# DatetimeIndex(['2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05',
#                '2020-03-06', '2020-03-09', '2020-03-10', '2020-03-11',
#                '2020-03-12', '2020-03-13',
#                ...
#                '2020-09-25', '2020-09-28', '2020-09-29', '2020-09-30',
#                '2020-10-01', '2020-10-02', '2020-10-05', '2020-10-06',
#                '2020-10-07', '2020-10-08'],
#               dtype='datetime64[ns]', name=u'Date', length=153, freq=None)

# %%
df2.columns
df3 = df2.copy()


for col in df3.columns: 
    df3['EMA60-'+col] = df3[col].ewm(span=60, adjust=False).mean()
    df3['EMA200-'+col] = df3[col].ewm(span=200, adjust=False).mean()

# %%
df4 = df3.tail(1)
df4
# Out:
# Symbols     AALI.JK  ABBA.JK  ABDA.JK  ABMM.JK  ACES.JK  ACST.JK  ADES.JK  \
# Date
# 2020-10-08  10675.0     50.0      NaN    855.0   1560.0    204.0   1180.0
#
# Symbols     ADHI.JK  ADMF.JK  ADMG.JK  ...  EMA60-YPAS.JK  EMA200-YPAS.JK  \
# Date                                   ...
# 2020-10-08    540.0   7500.0    141.0  ...     399.122154      353.913507
#
# Symbols     EMA60-YULE.JK  EMA200-YULE.JK  EMA60-ZBRA.JK  EMA200-ZBRA.JK  \
# Date
# 2020-10-08      199.97089      192.689434      50.064427       50.098975
#
# Symbols     EMA60-ZINC.JK  EMA200-ZINC.JK  EMA60-ZONE.JK  EMA200-ZONE.JK
# Date
# 2020-10-08     137.323662      182.528219      392.29021      414.860626
#
# [1 rows x 2106 columns]

# %%
# cross_ema200 = pd.DataFrame(columns=('Stock', 'Close', 'EMA200'))
# cross_ema60 = pd.DataFrame(columns=('Stock', 'Close', 'EMA60'))

cross_ema200 = {}
cross_ema60 = {}

list_ema200 = {}
list_ema60 = {}

# %%
stock = [
    "AALI.JK", "ABBA.JK", "ABDA.JK", "ABMM.JK", "ACES.JK", "ACST.JK", "ADES.JK", "ADHI.JK", "ADMF.JK", "ADMG.JK", "ADRO.JK", "AGAR.JK", "AGII.JK", "AGRO.JK", "AGRS.JK", "AHAP.JK", "AIMS.JK", "AISA.JK",
    "AKKU.JK", "AKPI.JK", "AKRA.JK", "AKSI.JK", "ALDO.JK", "ALKA.JK", "ALMI.JK", "ALTO.JK", "AMAG.JK", "AMAN.JK", "AMAR.JK", "AMFG.JK", "AMIN.JK", "AMOR.JK", "AMRT.JK", "ANDI.JK", "ANJT.JK", "ANTM.JK",
    "APEX.JK", "APIC.JK", "APII.JK", "APLI.JK", "APLN.JK", "ARGO.JK", "ARII.JK", "ARKA.JK", "ARMY.JK", "ARNA.JK", "ARTA.JK", "ARTI.JK", "ARTO.JK", "ASBI.JK", "ASDM.JK", "ASGR.JK", "ASII.JK", "ASJT.JK",
    "ASMI.JK", "ASPI.JK", "ASRI.JK", "ASRM.JK", "ASSA.JK", "ATIC.JK", "AUTO.JK", "AYLS.JK", "BABP.JK", "BACA.JK", "BAJA.JK","BALI.JK", "BAPA.JK", "BAPI.JK", "BATA.JK", "BAYU.JK", "BBCA.JK", "BBHI.JK",
    "BBKP.JK", "BBLD.JK", "BBMD.JK", "BBNI.JK", "BBRI.JK", "BBRM.JK", "BBSS.JK", "BBTN.JK", "BBYB.JK", "BCAP.JK", "BCIC.JK", "BCIP.JK", "BDMN.JK", "BEEF.JK", "BEKS.JK", "BELL.JK", "BESS.JK", "BEST.JK",
    "BFIN.JK", "BGTG.JK", "BHAT.JK", "BHIT.JK", "BIKA.JK", "BIMA.JK", "BINA.JK", "BIPI.JK", "BIPP.JK", "BIRD.JK", "BISI.JK", "BJBR.JK", "BJTM.JK", "BKDP.JK", "BKSL.JK", "BKSW.JK", "BLTA.JK", "BLTZ.JK",
    "BLUE.JK", "BMAS.JK", "BMRI.JK", "BMSR.JK", "BMTR.JK", "BNBA.JK", "BNBR.JK", "BNGA.JK", "BNII.JK", "BNLI.JK", "BOGA.JK", "BOLA.JK", "BOLT.JK", "BOSS.JK", "BPFI.JK", "BPII.JK", "BPTR.JK", "BRAM.JK",
    "BRIS.JK", "BRMS.JK", "BRNA.JK", "BRPT.JK", "BSDE.JK", "BSIM.JK", "BSSR.JK", "BSWD.JK", "BTEK.JK", "BTEL.JK", "BTON.JK", "BTPN.JK", "BTPS.JK", "BUDI.JK", "BUKK.JK", "BULL.JK", "BUMI.JK", "BUVA.JK",
    "PLIN.JK", "PMJS.JK", "PNBN.JK", "PNBS.JK", "PNIN.JK", "PNLF.JK", "PNSE.JK", "POLA.JK", "POLI.JK", "POLL.JK", "POLU.JK", "POLY.JK", "POOL.JK", "PORT.JK", "POSA.JK", "POWR.JK", "PPGL.JK", "PPRE.JK",
    "PPRO.JK", "PRAS.JK", "PRDA.JK", "PRIM.JK", "PSAB.JK", "PSDN.JK", "PSGO.JK", "PSKT.JK", "PSSI.JK", "PTBA.JK", "PTIS.JK", "PTPP.JK", "PTPW.JK", "PTRO.JK", "PTSN.JK", "PTSP.JK", "PUDP.JK", "PURA.JK",
    "PURE.JK", "PWON.JK", "PYFA.JK", "PZZA.JK", "RAJA.JK", "RALS.JK", "RANC.JK", "RBMS.JK", "RDTX.JK", "REAL.JK", "RELI.JK", "RICY.JK", "RIGS.JK", "RIMO.JK", "RISE.JK", "RMBA.JK", "RODA.JK", "RONY.JK",
    "ROTI.JK", "RUIS.JK", "SAFE.JK", "SAME.JK", "SAMF.JK", "SAPX.JK", "SATU.JK", "SBAT.JK", "SCCO.JK", "SCMA.JK", "SCPI.JK", "SDMU.JK", "SDPC.JK", "SDRA.JK", "SFAN.JK", "SGER.JK", "SGRO.JK", "SHID.JK",
    "SHIP.JK", "SIDO.JK", "SILO.JK", "SIMA.JK", "SIMP.JK", "SINI.JK", "SIPD.JK", "SKBM.JK", "SKLT.JK", "SKRN.JK", "SKYB.JK", "SLIS.JK", "SMAR.JK", "SMBR.JK", "SMCB.JK", "SMDM.JK", "SMDR.JK", "SMGR.JK",
    "SMKL.JK", "SMMA.JK", "SMMT.JK", "SMRA.JK", "SMRU.JK", "SMSM.JK", "SOCI.JK", "SOFA.JK", "SONA.JK", "SOSS.JK", "SOTS.JK", "SPMA.JK", "SPTO.JK", "SQMI.JK", "SRAJ.JK", "SRIL.JK", "SRSN.JK", "SRTG.JK",
    "SSIA.JK", "SSMS.JK", "SSTM.JK", "STAR.JK", "STTP.JK", "SUGI.JK", "SULI.JK", "SUPR.JK", "SURE.JK", "SWAT.JK", "TALF.JK", "TAMA.JK", "TAMU.JK", "TARA.JK", "TAXI.JK", "TBIG.JK", "TBLA.JK", "TBMS.JK",
    "TCID.JK", "TCPI.JK", "TDPM.JK", "TEBE.JK", "TECH.JK", "TELE.JK", "TFAS.JK", "TFCO.JK", "TGKA.JK", "TGRA.JK", "TIFA.JK", "TINS.JK","TIRA.JK", "TIRT.JK", "TKIM.JK", "TLKM.JK", "TMAS.JK", "TMPO.JK",
    "TNCA.JK", "TOBA.JK", "TOPS.JK", "TOTL.JK", "TOTO.JK", "TOWR.JK", "TOYS.JK", "TPIA.JK", "TPMA.JK", "TRAM.JK", "TRIL.JK", "TRIM.JK", "TRIN.JK", "TRIO.JK", "TRIS.JK", "TRST.JK", "TRUK.JK", "TRUS.JK",
    "TSPC.JK", "TUGU.JK", "TURI.JK", "UANG.JK", "UCID.JK", "ULTJ.JK", "UNIC.JK", "UNIT.JK", "UNSP.JK", "UNTR.JK", "UNVR.JK", "URBN.JK", "VICO.JK", "VINS.JK", "VIVA.JK", "VOKS.JK", "VRNA.JK", "WAPO.JK",
    "WEGE.JK", "WEHA.JK", "WICO.JK", "WIIM.JK", "WIKA.JK", "WINS.JK", "WOMF.JK", "WOOD.JK", "WOWS.JK", "WSBP.JK", "WSKT.JK", "WTON.JK", "YELO.JK", "YPAS.JK", "YULE.JK", "ZBRA.JK", "ZINC.JK", "ZONE.JK"
]

# %%
cnt_stock = len(stock)

for x in range(cnt_stock):
    ds = [col for col in df3.columns if stock[x] in col]    
    
    if df4[stock[x]].item() > df4['EMA200-'+stock[x]].item(): # Crossing EMA200
        # new_row_200 = pd.DataFrame([stock[x], df4[stock[x]+'.JK'].item(), df4['EMA200-'+stock[x]+'.JK'].item()])
        
        new_row_200 = {
            'Stock':stock[x]
            , 'Close':df4[stock[x]].item()
            , 'EMA200':df4['EMA200-'+stock[x]].item()
        }        
        
        cross_ema200[x] = new_row_200
    else:
        0
        
        
    if df4[stock[x]].item() >= df4['EMA60-'+stock[x]].item(): # Crossing EMA200
        new_row_60 = {
            'Stock':stock[x]
            , 'Close':df4[stock[x]].item()
            , 'EMA60':df4['EMA60-'+stock[x]].item()
        }

        cross_ema60[x] = new_row_60
    else:
        0

# %%
cross_ema200.items()
# Out:
# [(0, {'Close': 10675.0, 'EMA200': 9079.344525438437, 'Stock': 'AALI.JK'}),
#  (513, {'Close': 7800.0, 'EMA200': 7798.08043651138, 'Stock': 'POLL.JK'}),
#  (515, {'Close': 51.0, 'EMA200': 50.009950248756226, 'Stock': 'POLY.JK'}),
#  (4, {'Close': 1560.0, 'EMA200': 1505.3381153843573, 'Stock': 'ACES.JK'}),
#  (6, {'Close': 1180.0, 'EMA200': 953.0221792498004, 'Stock': 'ADES.JK'}),
#  (520, {'Close': 292.0, 'EMA200': 166.0417779434092, 'Stock': 'PPGL.JK'}),
#  (9, {'Close': 141.0, 'EMA200': 110.34940037007122, 'Stock': 'ADMG.JK'}),
#  (10, {'Close': 1130.0, 'EMA200': 1092.3007154091188, 'Stock': 'ADRO.JK'}),
#  (11, {'Close': 500.0, 'EMA200': 475.8980014589139, 'Stock': 'AGAR.JK'}),
#  (13, {'Close': 332.0, 'EMA200': 198.98974616701798, 'Stock': 'AGRO.JK'}),
#  (14, {'Close': 180.0, 'EMA200': 147.68575718422056, 'Stock': 'AGRS.JK'}),
#  (15, {'Close': 62.0, 'EMA200': 51.369632844240655, 'Stock': 'AHAP.JK'}),
#  (528, {'Close': 110.0, 'EMA200': 104.47348659352497, 'Stock': 'PSGO.JK'}),
# ...

# %%
from pandas.io.json import json_normalize

# Convert dictionary -> dataframe
cross_ema60_df = pd.DataFrame(list(cross_ema60.items()),columns = ['No','Value'])
cross_ema60_df

# Convert dataframe -> json
cross_ema60_df_normalize = json_normalize(cross_ema60_df['Value'])
cross_ema60_df_normalize
# Out:
#        Close        EMA60    Stock
# 0    10675.0  9938.472748  AALI.JK
# 1     7800.0  7109.285052  POLL.JK
# 2      995.0   859.657090  POLU.JK
# 3       51.0    50.032787  POLY.JK
# 4     1180.0  1095.324316  ADES.JK
# 5     7500.0  7456.723357  ADMF.JK
# 6      141.0   116.230250  ADMG.JK
# 7     1130.0  1128.090885  ADRO.JK
# 8      500.0   495.634892  AGAR.JK
# 9      500.0   498.347824  AGII.JK
# 10     332.0   288.688450  AGRO.JK
# 11     180.0   164.993763  AGRS.JK
# 12      62.0    52.411356  AHAP.JK
# 13     110.0   106.273537  PSGO.JK
# 14     212.0   193.507372  AISA.JK
# 15      50.0    50.000000  AKKU.JK
# 16     308.0   304.317313  AKPI.JK
# 17      50.0    50.000000  PSKT.JK
# 18     452.0   304.320353  AKSI.JK
# 19     396.0   386.774435  ALDO.JK
# 20     100.0    82.685782  SOFA.JK
# 21     212.0   211.373269  PTSN.JK
# 22     306.0   247.852124  AMAN.JK
# 23     318.0   227.776954  PURE.JK
# 24     290.0   271.358137  AMIN.JK
# 25    2050.0  2050.000000  AMOR.JK
# ...

# %%
cross_ema200


from pandas.io.json import json_normalize

# Convert dictionary -> dataframe
cross_ema200_df = pd.DataFrame(list(cross_ema200.items()),columns = ['No','Value'])
cross_ema200_df

# Convert dataframe -> json
cross_ema200_df_normalize = json_normalize(cross_ema200_df['Value'])
cross_ema200_df_normalize
# Out:
#        Close        EMA200    Stock
# 0    10675.0   9079.344525  AALI.JK
# 1     7800.0   7798.080437  POLL.JK
# 2       51.0     50.009950  POLY.JK
# 3     1560.0   1505.338115  ACES.JK
# 4     1180.0    953.022179  ADES.JK
# 5      292.0    166.041778  PPGL.JK
# 6      141.0    110.349400  ADMG.JK
# 7     1130.0   1092.300715  ADRO.JK
# 8      500.0    475.898001  AGAR.JK
# 9      332.0    198.989746  AGRO.JK
# 10     180.0    147.685757  AGRS.JK
# 11      62.0     51.369633  AHAP.JK
# 12     110.0    104.473487  PSGO.JK
# 13     212.0    177.939828  AISA.JK
# 14      50.0     50.000000  AKKU.JK
# 15    2610.0   2546.114948  AKRA.JK
# 16     452.0    283.965950  AKSI.JK
# 17    1385.0   1058.019157  PTPW.JK
# 18    1675.0   1501.659587  PTRO.JK
# 19     212.0    200.109432  PTSN.JK
# 20     306.0    206.473391  AMAN.JK
# 21     296.0    284.361921  AMAR.JK
# 22     790.0    555.333633  PYFA.JK
# 23    2050.0   2050.000000  AMOR.JK
# 24     124.0    105.563768  RAJA.JK
# ...

# %%
import smtplib

# %%
conn = smtplib.SMTP('smtp.gmail.com', 587)

# %%
type(conn)
# Out:
# instance

# %%
conn.ehlo()
# Out:
# (250,
#  'smtp.gmail.com at your service, [125.161.129.207]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %%
conn.starttls()
# Out:
# (220, '2.0.0 Ready to start TLS')

# %%
conn.login('Email Sender', '')
# Out:
# (235, '2.7.0 Accepted')

# %%
#from email.message import EmailMessage
from email.mime.text import MIMEText
from email.mime.application import MIMEApplication
from email.mime.multipart import MIMEMultipart
from smtplib import SMTP
import smtplib
import sys



#message = EmailMessage()
msg = MIMEMultipart()
msg['subject'] = 'Cross EMA200'
msg['from'] = 'Email Sender'
emaillist = 'Email Recipient'



html = """\
<html>
  <head></head>
  <body>
    {0}
  </body>
</html>
""".format(cross_ema200_df_normalize.to_html())

part1 = MIMEText(html, 'html')
msg.attach(part1)


conn.sendmail(msg['From'], emaillist , msg.as_string())
# Out:
# {}
